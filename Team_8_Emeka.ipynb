# %%
# Check Energy Data Columns and Sample Data
print("🔹 Energy Data Columns:")
print(table5_data.columns)

print("\n🔹 First 5 Rows of Energy Data:")
display(table5_data.head())
# Out:
# 🔹 Energy Data Columns:
# Index(['Table 5. Electric power industry generation by primary energy source, 1990 through 2023',
#        'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30',
#        'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34',
#        'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38'],
#       dtype='object')
#
# 🔹 First 5 Rows of Energy Data:
#   Table 5. Electric power industry generation by primary energy source, 1990 through 2023  \
# 0                                         California
# ...

# %%
# Check Wildfire Data Columns and Sample Data
print("🔹 Wildfire Data Columns:")
print(fire_incidents_data.columns)

print("\n🔹 First 5 Rows of Wildfire Data:")
display(fire_incidents_data.head())
# Out:
# 🔹 Wildfire Data Columns:
# Index(['AcresBurned', 'Year', 'Counties'], dtype='object')
#
# 🔹 First 5 Rows of Wildfire Data:
#    AcresBurned  Year     Counties
# 0     257314.0  2013     Tuolumne
# 1      30274.0  2013  Los Angeles
# 2      27531.0  2013    Riverside
# 3      27440.0  2013       Placer
# 4      24251.0  2013      Ventura

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fdf09050-d006-413d-85b5-fe32e8c2c83f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fdf09050-d006-413d-85b5-fe32e8c2c83f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'table 5xlsx (1).xlsx',
#  'California_Electrical_Energy_Generation_2001-Current_ADA (for web).xlsx',
#  'California_Fire_Incidents.csv',
#  'table 5xlsx.xlsx',
#  'drive',
#  'sample_data']

# %%
import pandas as pd

# Load Wildfire Data
wildfire_data = pd.read_csv('California_Fire_Incidents.csv')

# Load Energy Data
energy_data = pd.read_excel('California_Electrical_Energy_Generation_2001-Current_ADA (for web).xlsx')

# Load Table 5 (if needed)
table5_data = pd.read_excel('table 5xlsx.xlsx')

# Display first few rows of each dataset
print("\n🔹 Wildfire Data Sample:")
print(wildfire_data.head())

print("\n🔹 Energy Data Sample:")
print(energy_data.head())

print("\n🔹 Table 5 Data Sample:")
print(table5_data.head())
# Out:
# 🔹 Wildfire Data Sample:
#    AcresBurned  Active                                          AdminUnit  \
# 0     257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1      30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2      27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3      27440.0   False                              Tahoe National Forest
# 4      24251.0   False                       Ventura County Fire/CAL FIRE
#
#    AirTankers  ArchiveYear  CalFireIncident  \
# 0         NaN         2013             True
# 1         NaN         2013             True
# 2         NaN         2013             True
# 3         NaN         2013            False
# 4         NaN         2013             True
#
#                             CanonicalUrl  \
# 0         /incidents/2013/8/17/rim-fire/
# 1  /incidents/2013/5/30/powerhouse-fire/
# 2    /incidents/2013/7/15/mountain-fire/
# 3    /incidents/2013/8/10/american-fire/
# ...

# %%
#Clean Energy Data
energy_data_cleaned = energy_data.iloc[2:, [0, -1]].copy()  # Skip the first two rows to get the correct data

#Assign column names correctly
energy_data_cleaned.columns = ['Year', 'TotalGeneration']

#Convert the 'Year' column to numeric
energy_data_cleaned['Year'] = pd.to_numeric(energy_data_cleaned['Year'], errors='coerce')

#Drop rows with any NaN values (if any)
energy_data_cleaned = energy_data_cleaned.dropna()

#Check the cleaned data
print("Cleaned Energy Data:")
print(energy_data_cleaned.head())
# Out:
# Cleaned Energy Data:
# Empty DataFrame
# Columns: [Year, TotalGeneration]
# Index: []

# %%
# First, let's inspect the top rows of the dataset
print("Initial Rows of Energy Data:")
print(energy_data.head(10))  # Check the first 10 rows to understand the structure

# Skip the first two rows and take the correct rows from the dataset
energy_data_cleaned = energy_data.iloc[2:, [0, -1]].copy()  # Skip the first 2 rows
energy_data_cleaned.columns = ['Year', 'TotalGeneration']

# Convert 'Year' to numeric, coercing any errors into NaN
energy_data_cleaned['Year'] = pd.to_numeric(energy_data_cleaned['Year'], errors='coerce')

# Remove any rows with NaN values (if any)
energy_data_cleaned = energy_data_cleaned.dropna()

# Check if the data is cleaned correctly
print("Cleaned Energy Data:")
print(energy_data_cleaned.head())
# Out:
# Initial Rows of Energy Data:
#                          Unnamed: 0           2001          2002  \
# 0                               NaN            GWh           GWh
# 1  Total System Electric Generation  267414.199978  274416.65039
# 2         Total In-State Generation  202488.219978  186822.80693
# 3                  CA Hydroelectric   24987.848294   31359.46526
# 4                    CA Large Hydro    20143.99301     26003.018
# 5                    CA Small Hydro    4843.855284    5356.44726
# 6                        CA Nuclear      33293.819     34353.329
# 7                           CA Coal     2811.14861    3009.98811
# 8                            CA Oil        378.917         87.19
# 9                    CA Natural Gas  116157.865954   92498.06044
#
#             2003           2004           2005           2006           2007  \
# 0            GWh            GWh            GWh            GWh            GWh
# ...

# %%
wildfire_data_path = '/content/drive/MyDrive/California Fires Data/California_Fire_Incidents.csv'
energy_data_path = '/content/drive/MyDrive/California Fires Data/California_Electrical_Energy_Generation_2001-Current_ADA (for web).xlsx'
table5_data_path = '/content/drive/MyDrive/California Fires Data/table 5xlsx.xlsx'

# %%
# Load the wildfire data
wildfire_data = pd.read_csv(wildfire_data_path)

# Load the energy data
energy_data = pd.read_excel(energy_data_path)

# Load the table 5 data
table5_data = pd.read_excel(table5_data_path)

# %%
# Check the contents of the directory
import os

path_to_folder = '/content/drive/MyDrive/California Fires Data/'
os.listdir(path_to_folder)
# Out:
# ['California_Electrical_Energy_Generation_2001-Current_ADA (for web).xlsx',
#  'table 5xlsx.xlsx',
#  'California_Fire_Incidents.csv']

# %%
import pandas as pd

# Load Wildfire Data (CSV)
wildfire_data_path = '/content/drive/MyDrive/California Fires Data/California_Fire_Incidents.csv'
wildfire_data = pd.read_csv(wildfire_data_path)
print("Wildfire Data Sample:")
print(wildfire_data.head())

# Load Energy Data (Excel)
energy_data_path = '/content/drive/MyDrive/California Fires Data/California_Electrical_Energy_Generation_2001-Current_ADA (for web).xlsx'
energy_data = pd.read_excel(energy_data_path)
print("\n Energy Data Sample:")
print(energy_data.head())

# Load Table 5 Data (Excel)
table5_data_path = '/content/drive/MyDrive/California Fires Data/table 5xlsx.xlsx'
table5_data = pd.read_excel(table5_data_path)
print("\n Table 5 Data Sample:")
print(table5_data.head())
# Out:
# Wildfire Data Sample:
#    AcresBurned  Active                                          AdminUnit  \
# 0     257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1      30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2      27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3      27440.0   False                              Tahoe National Forest
# 4      24251.0   False                       Ventura County Fire/CAL FIRE
#
#    AirTankers  ArchiveYear  CalFireIncident  \
# 0         NaN         2013             True
# 1         NaN         2013             True
# 2         NaN         2013             True
# 3         NaN         2013            False
# 4         NaN         2013             True
#
#                             CanonicalUrl  \
# 0         /incidents/2013/8/17/rim-fire/
# 1  /incidents/2013/5/30/powerhouse-fire/
# 2    /incidents/2013/7/15/mountain-fire/
# 3    /incidents/2013/8/10/american-fire/
# ...

# %%
import pandas as pd

# Load the CSV data for Wildfires
wildfire_data_path = '/content/drive/MyDrive/California Fires Data/California_Fire_Incidents.csv'
wildfire_data = pd.read_csv(wildfire_data_path)

# Load the Excel data for Energy Generation (if needed, update the path as required)
energy_data_path = '/content/drive/MyDrive/California Fires Data/California_Electrical_Energy_Generation_2001-Current_ADA (for web).xlsx'
energy_data = pd.read_excel(energy_data_path)

# Display the first few rows of both datasets to ensure they loaded correctly
print(wildfire_data.head())
print(energy_data.head())
# Out:
#    AcresBurned  Active                                          AdminUnit  \
# 0     257314.0   False  Stanislaus National Forest/Yosemite National Park
# 1      30274.0   False  USFS Angeles National Forest/Los Angeles Count...
# 2      27531.0   False  CAL FIRE Riverside Unit / San Bernardino Natio...
# 3      27440.0   False                              Tahoe National Forest
# 4      24251.0   False                       Ventura County Fire/CAL FIRE
#
#    AirTankers  ArchiveYear  CalFireIncident  \
# 0         NaN         2013             True
# 1         NaN         2013             True
# 2         NaN         2013             True
# 3         NaN         2013            False
# 4         NaN         2013             True
#
#                             CanonicalUrl  \
# 0         /incidents/2013/8/17/rim-fire/
# 1  /incidents/2013/5/30/powerhouse-fire/
# 2    /incidents/2013/7/15/mountain-fire/
# 3    /incidents/2013/8/10/american-fire/
# ...

# %%
# Clean the relevant columns
wildfire_data_cleaned = wildfire_data[['ArchiveYear', 'AcresBurned']]

# Remove any rows with missing data
wildfire_data_cleaned = wildfire_data_cleaned.dropna(subset=['ArchiveYear', 'AcresBurned'])

# Rename 'ArchiveYear' to 'Year'
wildfire_data_cleaned = wildfire_data_cleaned.rename(columns={'ArchiveYear': 'Year'})

# Aggregate acres burned by year
annual_wildfires = wildfire_data_cleaned.groupby('Year')['AcresBurned'].sum().reset_index()

# Display the cleaned data
print(annual_wildfires.head())
# Out:
#    Year  AcresBurned
# 0  2013     527745.0
# 1  2014     448715.0
# 2  2015     574503.0
# 3  2016     505927.0
# 4  2017    1793915.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(os.listdir('/content/drive/MyDrive/California Fires Data'))
# Out:
# ['California_Electrical_Energy_Generation_2001-Current_ADA (for web).xlsx', 'table 5xlsx.xlsx', 'California_Fire_Incidents.csv']

# %%
wildfire_data = pd.read_csv('/content/drive/MyDrive/California Fires Data/California_Fire_Incidents.csv')

# %%
# Check the sheet names
excel_file = pd.ExcelFile('/content/drive/MyDrive/California Fires Data/California_Electrical_Energy_Generation_2001-Current_ADA (for web).xlsx')
print(excel_file.sheet_names)
# Out:
# ['For Website']

# %%
# Load the specific sheet 'For Website' for energy data
energy_data = pd.read_excel(energy_data_path, sheet_name='For Website')

# Display the first few rows to inspect the data
print(energy_data.head())

# Clean the energy data by selecting relevant columns: 'Year' and 'Total Generation'
energy_data_cleaned = energy_data.iloc[2:, [0, -1]].copy()  # Skip the first two rows and take the last column (2023 data)

# Assign appropriate column names
energy_data_cleaned.columns = ['Year', 'TotalGeneration']

# Convert 'Year' to numeric and coerce errors into NaN
energy_data_cleaned['Year'] = pd.to_numeric(energy_data_cleaned['Year'], errors='coerce')

# Drop rows with NaN values
energy_data_cleaned = energy_data_cleaned.dropna()

# Display the cleaned energy data
print(energy_data_cleaned.head())
# Out:
#                          Unnamed: 0           2001          2002  \
# 0                               NaN            GWh           GWh
# 1  Total System Electric Generation  267414.199978  274416.65039
# 2         Total In-State Generation  202488.219978  186822.80693
# 3                  CA Hydroelectric   24987.848294   31359.46526
# 4                    CA Large Hydro    20143.99301     26003.018
#
#             2003           2004           2005           2006           2007  \
# 0            GWh            GWh            GWh            GWh            GWh
# 1  279694.120436  290084.377697  289160.380401  298318.184473  304909.199259
# 2  194293.540436  198795.860497  202079.302401  218603.831473  212692.625259
# 3    36320.83233    34489.95278    40262.53724    48558.57309   27106.126333
# 4    30325.31899    28944.54754    33334.40601    40951.54965    22640.49901
#
#             2008           2009  ...           2014           2015  \
# ...

# %%
# Load the Excel data (again for safety)
energy_data = pd.read_excel('/content/drive/MyDrive/California Fires Data/California_Electrical_Energy_Generation_2001-Current_ADA (for web).xlsx', sheet_name='For Website')

# Check the first 10 rows to understand the structure
print("Initial rows of Energy Data:")
print(energy_data.head(10))

# Capture the correct data rows: skip the first two rows and target the data for the years
energy_data_cleaned = energy_data.iloc[2:, [0] + list(range(1, energy_data.shape[1]))].copy()

# Now let's assign column names: first column will be 'Energy Source', then 'Year' columns
energy_data_cleaned.columns = ['Energy Source'] + [str(year) for year in range(2001, 2024)]

# Melt the dataframe to make 'Year' and 'Total Generation' as columns
energy_data_melted = energy_data_cleaned.melt(id_vars=['Energy Source'], var_name='Year', value_name='TotalGeneration')

# Convert 'Year' to numeric
energy_data_melted['Year'] = pd.to_numeric(energy_data_melted['Year'], errors='coerce')

# Remove rows with NaN values (if any)
energy_data_melted = energy_data_melted.dropna()

# Check the cleaned data
print("Cleaned Energy Data:")
print(energy_data_melted.head())
# Out:
# Initial rows of Energy Data:
#                          Unnamed: 0           2001          2002  \
# 0                               NaN            GWh           GWh
# 1  Total System Electric Generation  267414.199978  274416.65039
# 2         Total In-State Generation  202488.219978  186822.80693
# 3                  CA Hydroelectric   24987.848294   31359.46526
# 4                    CA Large Hydro    20143.99301     26003.018
# 5                    CA Small Hydro    4843.855284    5356.44726
# 6                        CA Nuclear      33293.819     34353.329
# 7                           CA Coal     2811.14861    3009.98811
# 8                            CA Oil        378.917         87.19
# 9                    CA Natural Gas  116157.865954   92498.06044
#
#             2003           2004           2005           2006           2007  \
# 0            GWh            GWh            GWh            GWh            GWh
# ...

# %%
# Check the column names of both datasets
print("Annual Wildfires Columns:")
print(annual_wildfires.columns)

print("\nEnergy Data Columns:")
print(energy_data_cleaned.columns)
# Out:
# Annual Wildfires Columns:
# Index(['Year', 'AcresBurned'], dtype='object')
#
# Energy Data Columns:
# Index(['Energy Source', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
# Reshape the energy data to have a 'Year' column and 'TotalGeneration' column
energy_data_cleaned = energy_data_cleaned.melt(id_vars=["Energy Source"],
                                               value_vars=[str(year) for year in range(2001, 2024)],
                                               var_name="Year",
                                               value_name="TotalGeneration")

# Convert 'Year' to numeric
energy_data_cleaned['Year'] = pd.to_numeric(energy_data_cleaned['Year'], errors='coerce')

# Remove any rows with NaN values
energy_data_cleaned = energy_data_cleaned.dropna()

# Check the reshaped data
print(energy_data_cleaned.head())
# Out:
#                Energy Source  Year TotalGeneration
# 0  Total In-State Generation  2001   202488.219978
# 1           CA Hydroelectric  2001    24987.848294
# 2             CA Large Hydro  2001     20143.99301
# 3             CA Small Hydro  2001     4843.855284
# 4                 CA Nuclear  2001       33293.819

# %%
# Merge the wildfire data with the reshaped energy data on the "Year" column
merged_data = pd.merge(annual_wildfires, energy_data_cleaned, on='Year')

# Display the merged data
print("Merged Data Sample:")
print(merged_data.head())
# Out:
# Merged Data Sample:
#    Year  AcresBurned              Energy Source TotalGeneration
# 0  2013     527745.0  Total In-State Generation   199615.889405
# 1  2013     527745.0           CA Hydroelectric     24100.86539
# 2  2013     527745.0             CA Large Hydro     20318.64819
# 3  2013     527745.0             CA Small Hydro       3782.2172
# 4  2013     527745.0                 CA Nuclear       17860.072

# %%
print(merged_data.columns)
# Out:
# Index(['Year', 'AcresBurned', 'Energy Source', 'TotalGeneration'], dtype='object')

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Extracting relevant columns for linear regression
X = merged_data[['AcresBurned']]  # Independent variable
y = merged_data['TotalGeneration']  # Dependent variable

# Initialize the Linear Regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)

# Predict the total generation based on wildfire acres burned
y_pred = model.predict(X)

# Display the regression coefficients
print(f"Intercept: {model.intercept_}")
print(f"Coefficient: {model.coef_}")

# Create the plot with enhanced aesthetics
plt.figure(figsize=(12, 8))

# Scatter plot of actual data with transparency and black edges
plt.scatter(X, y, color='orange', label='Actual Data', alpha=0.7, edgecolors='black', s=100)

# Plot the regression line with a thicker, more noticeable line
plt.plot(X, y_pred, color='dodgerblue', linewidth=3, label='Regression Line')

# Title and labels with improved fonts
plt.title('Linear Regression: Acres Burned vs Energy Generation (California)', fontsize=18, weight='bold')
plt.xlabel('Acres Burned', fontsize=14)
plt.ylabel('Total Generation (GWh)', fontsize=14)

# Customize the gridlines
plt.grid(True, which='both', linestyle='--', linewidth=0.6)

# Set background color and style for the plot
plt.gca().set_facecolor('whitesmoke')

# Customize the legend
plt.legend(fontsize=12, loc='upper left')

# Tight layout to ensure everything fits nicely
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# Intercept: 24537.30216926355
# Coefficient: [3.64144733e-05]

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Extracting relevant columns for linear regression
X = merged_data[['AcresBurned']]  # Independent variable
y = merged_data['TotalGeneration']  # Dependent variable

# Initialize the Linear Regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X, y)

# Predict the total generation based on wildfire acres burned
y_pred = model.predict(X)

# Display the regression coefficients
print(f"Intercept: {model.intercept_}")
print(f"Coefficient: {model.coef_}")

# Plot the results
plt.figure(figsize=(12, 6))
plt.scatter(X, y, color='blue', label='Actual data')  # Scatter plot of actual data
plt.plot(X, y_pred, color='red', label='Regression line')  # Plot the regression line
plt.xlabel('Acres Burned')
plt.ylabel('Total Generation (GWh)')
plt.title('Linear Regression: Acres Burned vs Energy Generation (California)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Intercept: 24537.30216926355
# Coefficient: [3.64144733e-05]

# %%
# Example for Hydroelectric Energy generation
hydro_data = merged_data[merged_data['Energy Source'] == 'CA Hydroelectric']
X_hydro = hydro_data[['AcresBurned']]
y_hydro = hydro_data['TotalGeneration']

# Fit linear regression model
model_hydro = LinearRegression()
model_hydro.fit(X_hydro, y_hydro)

# Plot the regression line
plt.scatter(X_hydro, y_hydro, color='blue', label='Hydroelectric data')
plt.plot(X_hydro, model_hydro.predict(X_hydro), color='red', label='Regression Line')
plt.xlabel('Acres Burned')
plt.ylabel('Hydroelectric Energy Generation (GWh)')
plt.title('Impact of Wildfires on Hydroelectric Energy Generation')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Assuming 'merged_data' is already available and cleaned
# Step 1: Calculate the "Severity" of the wildfire (just based on Acres Burned in this case)
merged_data['Severity'] = merged_data['AcresBurned']  # Using Acres Burned as severity

# Step 2: Prepare the data for linear regression
# The independent variable (X) is "Severity" (Acres Burned) and the dependent variable (y) is "TotalGeneration" (energy loss).
X_severity = merged_data[['Severity']]  # Independent variable
y_loss = merged_data['TotalGeneration']  # Dependent variable

# Step 3: Initialize and fit the linear regression model
model_severity = LinearRegression()
model_severity.fit(X_severity, y_loss)

# Step 4: Plot the regression line
plt.figure(figsize=(10, 6))
plt.scatter(X_severity, y_loss, color='orange', label='Energy loss data')
plt.plot(X_severity, model_severity.predict(X_severity), color='blue', label='Regression Line')
plt.xlabel('Wildfire Severity (Acres Burned)')
plt.ylabel('Energy Loss (GWh)')
plt.title('Impact of Wildfire Severity on Energy Loss')
plt.legend()
plt.grid(True)
plt.show()

# Print model coefficients (optional)
print(f"Intercept: {model_severity.intercept_}")
print(f"Coefficient: {model_severity.coef_}")
# Out:
# Intercept: 24537.30216926355
# Coefficient: [3.64144733e-05]
